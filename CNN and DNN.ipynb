# %%
#TAN JIA JUN TP063792
#dataset link: https://www.kaggle.com/datasets/ravidussilva/real-ai-art/data

# %%
# import zipfile
# import os

# def unzip_file(zip_file_path, extract_to):
#     with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# # Example usage
# zip_file_path = "C:\\Users\\erict\\Downloads\\Real_AI_SD_LD_Dataset.zip"
# extract_to = "C:\\Users\\erict\\OneDrive - Asia Pacific University\\Documents\\level 3\\deep learning\\assignment"

# unzip_file(zip_file_path, extract_to)

# %%
import numpy as np
import pandas as pd
import os

train="C:\\Users\\erict\\OneDrive - Asia Pacific University\\Documents\\level 3\\deep learning\\assignment\\train"
test="C:\\Users\\erict\\OneDrive - Asia Pacific University\\Documents\\level 3\\deep learning\\assignment\\test"
# Out:
# Running cells with 'pythonProject1-X3S3Gi3k (Python 3.10.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/user10/.virtualenvs/pythonProject1-X3S3Gi3k/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
train_labels = os.listdir(train)
test_labels = os.listdir(test)

print("Original Training labels:", train_labels)
print("Original Testing labels:", test_labels)
# Out:
# Original Training labels: ['AI_LD_art_nouveau', 'AI_LD_baroque', 'AI_LD_expressionism', 'AI_LD_impressionism', 'AI_LD_post_impressionism', 'AI_LD_realism', 'AI_LD_renaissance', 'AI_LD_romanticism', 'AI_LD_surrealism', 'AI_LD_ukiyo-e', 'art_nouveau', 'baroque', 'expressionism', 'impressionism', 'post_impressionism', 'realism', 'renaissance', 'romanticism', 'surrealism', 'ukiyo_e']
# Original Testing labels: ['AI_LD_art_nouveau', 'AI_LD_baroque', 'AI_LD_expressionism', 'AI_LD_impressionism', 'AI_LD_post_impressionism', 'AI_LD_realism', 'AI_LD_renaissance', 'AI_LD_romanticism', 'AI_LD_surrealism', 'AI_LD_ukiyo-e', 'art_nouveau', 'baroque', 'expressionism', 'impressionism', 'post_impressionism', 'realism', 'renaissance', 'romanticism', 'surrealism', 'ukiyo_e']

# %%
def count_images(directory):
    label_counts = {}
    # Iterate over each label's subdirectory
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        # Check if it's a directory and not a hidden file or directory
        if os.path.isdir(label_path) and not label.startswith('.'):
            # Count the number of files in each label directory
            num_images = len([file for file in os.listdir(label_path) if not file.startswith('.')])
            label_counts[label] = num_images
    return label_counts

# Get the number of images for each label in the training and testing datasets
train_label_counts = count_images(train)
test_label_counts = count_images(test)

print("Training label counts:", train_label_counts)
print("Testing label counts:", test_label_counts)
# Out:
# Training label counts: {'AI_LD_art_nouveau': 4992, 'AI_LD_baroque': 4960, 'AI_LD_expressionism': 5116, 'AI_LD_impressionism': 5208, 'AI_LD_post_impressionism': 4844, 'AI_LD_realism': 5232, 'AI_LD_renaissance': 5416, 'AI_LD_romanticism': 5436, 'AI_LD_surrealism': 5384, 'AI_LD_ukiyo-e': 5504, 'art_nouveau': 5000, 'baroque': 5000, 'expressionism': 5000, 'impressionism': 5000, 'post_impressionism': 5000, 'realism': 5000, 'renaissance': 5000, 'romanticism': 5000, 'surrealism': 5000, 'ukiyo_e': 5000}
# ...

# %%
train_human = []
train_ai = []

# Traverse all directories
for directory in os.listdir(train):
    # Check if the directory represents human-drawn images
    if not directory.startswith('AI_'):
        train_human.append(os.path.join(train, directory))
    # Check if the directory represents AI-generated images
    else:
        train_ai.append(os.path.join(train, directory))
# Print directory lists
print("Train directories containing human-drawn images:")
for i, directory in enumerate(train_human):
    print(f"{i}. {directory}")

print("\nTrain directories containing AI-generated images:")
for i, directory in enumerate(train_ai):
    print(f"{i}. {directory}")
# Out:
# Train directories containing human-drawn images:
# 0. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\art_nouveau
# 1. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\baroque
# 2. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\expressionism
# 3. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\impressionism
# 4. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\post_impressionism
# 5. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\realism
# 6. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\renaissance
# 7. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\train\romanticism
# ...

# %%
test_human = []
test_ai = []

# Traverse all directories
for directory in os.listdir(test):
    # Check if the directory represents human-drawn images
    if not directory.startswith('AI_'):
        test_human.append(os.path.join(test, directory))
    # Check if the directory represents AI-generated images
    else:
        test_ai.append(os.path.join(test, directory))
# Print directory lists
print("Test directories containing human-drawn images:")
for i, directory in enumerate(test_human):
    print(f"{i}. {directory}")

print("\nTest directories containing AI-generated images:")
for i, directory in enumerate(test_ai):
    print(f"{i}. {directory}")
# Out:
# Test directories containing human-drawn images:
# 0. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\art_nouveau
# 1. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\baroque
# 2. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\expressionism
# 3. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\impressionism
# 4. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\post_impressionism
# 5. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\realism
# 6. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\renaissance
# 7. C:\Users\erict\OneDrive - Asia Pacific University\Documents\level 3\deep learning\assignment\test\romanticism
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_images(images, title):
    fig, axes = plt.subplots(3, 3, figsize=(10, 10))
    fig.suptitle(title)

    for i, ax in enumerate(axes.flat):
        if i < len(images):
            image_path = os.path.join(images[i], os.listdir(images[i])[0])
            image = mpimg.imread(image_path)
            ax.imshow(image)
            ax.axis('off')
            ax.set_title(f"Image {i}")
        else:
            ax.axis('off')

    plt.show()

# Visualize human-drawn images in a 3x3 grid
plot_images(train_human, "Train Human Images")

# Visualize AI-generated images in a 3x3 grid
plot_images(train_ai, "Train AI Images")

# Similarly, you can visualize images in the test_human and test_ai lists

# %%
# Initialize lists to store file paths and labels
file_paths = []
labels = []

# Initialize an empty DataFrame for train_data
train_data = pd.DataFrame(columns=['File_Path', 'Label'])

# Label files under train_human as "human"
for directory in train_human:
    for file in os.listdir(directory):
        file_paths.append(os.path.join(directory, file))
        labels.append('human')

# Label files under train_ai as "AI"
for directory in train_ai:
    for file in os.listdir(directory):
        file_paths.append(os.path.join(directory, file))
        labels.append('AI')

# Create a DataFrame with file paths and labels
data = pd.DataFrame({'File_Path': file_paths, 'Label': labels})

# Concatenate data with train_data
train_data = pd.concat([train_data, data], ignore_index=True)

# %%
# Count the number of files under each label
label_counts = train_data['Label'].value_counts()

# Print the counts
print("Counts of files under each label:")
print(label_counts)
# Out:
# Counts of files under each label:
# Label
# AI       52092
# human    50000
# Name: count, dtype: int64

# %%
# Initialize lists to store file paths and labels
file_paths = []
labels = []

# Initialize an empty DataFrame for test_data
test_data = pd.DataFrame(columns=['File_Path', 'Label'])

# Label files under test_human as "human"
for directory in test_human:
    for file in os.listdir(directory):
        file_paths.append(os.path.join(directory, file))
        labels.append('human')

# Label files under test_ai as "AI"
for directory in test_ai:
    for file in os.listdir(directory):
        file_paths.append(os.path.join(directory, file))
        labels.append('AI')

# Create a DataFrame with file paths and labels
data = pd.DataFrame({'File_Path': file_paths, 'Label': labels})

# Concatenate data with test_data
test_data = pd.concat([test_data, data], ignore_index=True)

# %%
# Count the number of files under each label
label_counts_test = test_data['Label'].value_counts()

# Print the counts
print("Counts of files under each label:")
print(label_counts_test)
# Out:
# Counts of files under each label:
# Label
# human    10000
# AI       10000
# Name: count, dtype: int64

# %% [markdown]
# ## **Reducing data and balancing data**

# %% [markdown]
# # **train data**

# %%
np.random.seed(42)

# Number of rows to drop for the 'AI' label
num_rows_to_drop = 2092

# Get the indices of rows with the 'AI' label
ai_indices = train_data[train_data['Label'] == 'AI'].index

# Randomly select indices to drop using the specified seed
indices_to_drop = np.random.choice(ai_indices, num_rows_to_drop, replace=False)

# Drop the selected rows from the DataFrame
train_data.drop(indices_to_drop, inplace=True)

# Reset the index of the DataFrame after dropping rows
train_data.reset_index(drop=True, inplace=True)

# %%
# Count the number of files under each label
label_counts = train_data['Label'].value_counts()

# Print the counts
print("Counts of files under each label:")
print(label_counts)
# Out:
# Counts of files under each label:
# Label
# human    50000
# AI       50000
# Name: count, dtype: int64

# %% [markdown]
# ## **Creating train and test**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator instance for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalization: Scale pixel values from [0, 255] to [0, 1] range, aiding model learning
)

# Create an ImageDataGenerator instance for testing data
test_datagen = ImageDataGenerator(
    rescale=1./255  # For testing data, typically only normalization is needed
)

# %%
train_dataset = train_datagen.flow_from_dataframe(
    dataframe=train_data,
    x_col='File_Path',  # Column containing file paths
    y_col='Label',     # Column containing labels
    target_size=(128, 128),  # Resizing images to 224x224
    batch_size=64,
    class_mode='categorical',  # Categorical mode for multi-class classification
    shuffle=True  # Shuffle training data
)

test_dataset = test_datagen.flow_from_dataframe(
    dataframe=test_data,
    target_size=(128, 128),  # Resizing images to 224x224
    x_col='File_Path',  # Column containing file paths
    y_col='Label',     # Column containing labels
    batch_size=64,
    class_mode='categorical',  # Categorical mode for multi-class classification
    shuffle=False  # Don't shuffle testing data
)
# Out:
# Found 100000 validated image filenames belonging to 2 classes.
# Found 20000 validated image filenames belonging to 2 classes.

# %%
print(train_dataset.class_indices)
print(test_dataset.class_indices)
# Out:
# {'AI': 0, 'human': 1}
# {'AI': 0, 'human': 1}

# %% [markdown]
# # **CNN basic Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Initialize the model
model = Sequential()

# Add convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))  # Assuming RGB images
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flatten the output of convolutional layers
model.add(Flatten())

# Add dense layers
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='softmax'))  # Assuming `num_classes` is the number of output classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# ...
# Total params: 3,313,026
# Trainable params: 3,313,026
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_dataset,
    epochs=10,
    validation_data=test_dataset
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 276s 172ms/step - loss: 0.2876 - accuracy: 0.8740 - val_loss: 0.2257 - val_accuracy: 0.9105
# Epoch 2/10
# 1563/1563 [==============================] - 304s 194ms/step - loss: 0.1575 - accuracy: 0.9377 - val_loss: 0.1261 - val_accuracy: 0.9507
# Epoch 3/10
# 1563/1563 [==============================] - 178s 114ms/step - loss: 0.1098 - accuracy: 0.9572 - val_loss: 0.1351 - val_accuracy: 0.9475
# Epoch 4/10
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.0787 - accuracy: 0.9700 - val_loss: 0.1080 - val_accuracy: 0.9567
# Epoch 5/10
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.0584 - accuracy: 0.9782 - val_loss: 0.0822 - val_accuracy: 0.9693
# Epoch 6/10
# 1563/1563 [==============================] - 162s 103ms/step - loss: 0.0439 - accuracy: 0.9840 - val_loss: 0.0764 - val_accuracy: 0.9734
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
# # Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# # Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred_probs = model.predict(test_dataset)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)



# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 20s 63ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.97      0.98      0.98     10000
#      class 1       0.98      0.97      0.98     10000
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# Initialize the model
model = Sequential()
# Add convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flatten the output of convolutional layers
model.add(Flatten())
# Add dense layers with dropout
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout with rate 0.5
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout with rate 0.5
model.add(Dense(2, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 126, 126, 32)      896
#
#  batch_normalization_5 (Batc  (None, 126, 126, 32)     128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 128)               3211392
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
# ...

# %%
history = model.fit(
    train_dataset,
    epochs=10,
    validation_data=test_dataset
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 149s 95ms/step - loss: 0.3309 - accuracy: 0.8695 - val_loss: 0.2342 - val_accuracy: 0.9039
# Epoch 2/10
# 1563/1563 [==============================] - 147s 94ms/step - loss: 0.1250 - accuracy: 0.9575 - val_loss: 0.6673 - val_accuracy: 0.7223
# Epoch 3/10
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.0758 - accuracy: 0.9761 - val_loss: 0.0735 - val_accuracy: 0.9758
# Epoch 4/10
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.0569 - accuracy: 0.9822 - val_loss: 0.0552 - val_accuracy: 0.9816
# Epoch 5/10
# 1563/1563 [==============================] - 154s 99ms/step - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.1046 - val_accuracy: 0.9607
# Epoch 6/10
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.0389 - accuracy: 0.9883 - val_loss: 0.0559 - val_accuracy: 0.9808
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
# # Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# # Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred_probs = model.predict(test_dataset)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)



# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 31s 99ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.92      1.00      0.96     10000
#      class 1       1.00      0.92      0.96     10000
#
#     accuracy                           0.96     20000
#    macro avg       0.96      0.96      0.96     20000
# weighted avg       0.96      0.96      0.96     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## **Grid Search**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Define the hyperparameter grid
dropout_rates1 = [0.4,0.5,0.6]
dropout_rates2 = [0.4,0.5,0.6]

# Placeholder to store the evaluation results
results = []
histories = []

# Grid search over the hyperparameters
for dropout_rate1 in dropout_rates1:
    for dropout_rate2 in dropout_rates2:
        model = Sequential([
            Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
            BatchNormalization(),
            MaxPooling2D((2, 2)),
            Conv2D(64, (3, 3), activation='relu'),
            BatchNormalization(),
            MaxPooling2D((2, 2)),
            Conv2D(128, (3, 3), activation='relu'),
            MaxPooling2D((2, 2)),

            Flatten(),
            Dense(128, activation='relu'),
            Dropout(dropout_rate1),
            Dense(64, activation='relu'),
            Dropout(dropout_rate2),
            Dense(2, activation='softmax')
        ])
        
        model.compile(
            optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Assuming you have train_dataset and test_dataset
        # Fit the model
        history = model.fit(
            train_dataset,
            epochs=10,
            validation_data=test_dataset,
            callbacks=[early_stopping],
            verbose=1  # Set verbose to 1 to print out the progress
        )
        
        # Store the history
        histories.append(history)
        
        # Evaluate the model on the validation data
        val_accuracy = model.evaluate(test_dataset, verbose=0)[1]
        
        # Store the results
        results.append({
            'dropout_rate1': dropout_rate1,
            'dropout_rate2': dropout_rate2,
            'validation_accuracy': val_accuracy
        })

# Identify the best configuration
best_result = max(results, key=lambda x: x['validation_accuracy'])
print("Best configuration:", best_result)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 216s 138ms/step - loss: 0.3007 - accuracy: 0.8839 - val_loss: 0.1993 - val_accuracy: 0.9180
# Epoch 2/10
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.1146 - accuracy: 0.9595 - val_loss: 0.7890 - val_accuracy: 0.7669
# Epoch 3/10
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.0705 - accuracy: 0.9761 - val_loss: 2.5990 - val_accuracy: 0.6266
# Epoch 4/10
# 1563/1563 [==============================] - 146s 94ms/step - loss: 0.0443 - accuracy: 0.9855 - val_loss: 0.0610 - val_accuracy: 0.9784
# Epoch 5/10
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.3312 - val_accuracy: 0.8911
# Epoch 6/10
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.0236 - val_accuracy: 0.9929
# Epoch 7/10
# ...

# %%
# Plot training & validation accuracy values for the best model
best_model_index = results.index(best_result)
best_history = histories[best_model_index]


# Plot training & validation accuracy values
plt.plot(best_history.history['accuracy'])
plt.plot(best_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(best_history.history['loss'])
plt.plot(best_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
# Get the best model
best_model = model

# Assuming you have already trained and obtained predictions from your best model

# Get predicted probabilities for the test dataset
y_pred_probs = best_model.predict(test_dataset)

# Convert probabilities to class labels (assuming binary classification)
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels from the test dataset
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your actual class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 20s 63ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.97      0.91      0.94     10000
#      class 1       0.92      0.97      0.94     10000
#
#     accuracy                           0.94     20000
#    macro avg       0.95      0.94      0.94     20000
# weighted avg       0.95      0.94      0.94     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## **DNN model**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input

# Define the model
model = Sequential([
    Input(shape=(128, 128, 3)),  # Input layer specifying the input shape
    Flatten(),  # Flatten the input images
    Dense(512, activation='relu'),  # Hidden layer with 512 units and ReLU activation
    Dense(256, activation='relu'),  # Hidden layer with 256 units and ReLU activation
    Dense(128, activation='relu'),  # Hidden layer with 128 units and ReLU activation
    Dense(64, activation='relu'),   # Hidden layer with 64 units and ReLU activation
    Dense(2, activation='softmax')  # Output layer with 2 units (assuming 2 classes) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',  # Adam optimizer
              loss='categorical_crossentropy',  # Categorical cross-entropy loss function
              metrics=['accuracy'])  # Monitor accuracy during training

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 49152)             0
#
#  dense_5 (Dense)             (None, 512)               25166336
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 2)                 130
#
# ...
# Total params: 25,338,946
# Trainable params: 25,338,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_dataset,
    epochs=10,  # Number of training epochs
    validation_data=test_dataset  # Use the test dataset for validation during training
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 105s 66ms/step - loss: 0.6710 - accuracy: 0.6645 - val_loss: 0.5296 - val_accuracy: 0.7286
# Epoch 2/10
# 1563/1563 [==============================] - 107s 68ms/step - loss: 0.5081 - accuracy: 0.7430 - val_loss: 0.4647 - val_accuracy: 0.7736
# Epoch 3/10
# 1563/1563 [==============================] - 97s 62ms/step - loss: 0.4631 - accuracy: 0.7778 - val_loss: 0.4473 - val_accuracy: 0.7902
# Epoch 4/10
# 1563/1563 [==============================] - 100s 64ms/step - loss: 0.4312 - accuracy: 0.8009 - val_loss: 0.4405 - val_accuracy: 0.7984
# Epoch 5/10
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.4036 - accuracy: 0.8167 - val_loss: 0.4152 - val_accuracy: 0.8157
# Epoch 6/10
# 1563/1563 [==============================] - 98s 62ms/step - loss: 0.3852 - accuracy: 0.8281 - val_loss: 0.3904 - val_accuracy: 0.8237
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
# # Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# # Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred_probs = model.predict(test_dataset)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)



# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 16s 51ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.90      0.74      0.81     10000
#      class 1       0.78      0.91      0.84     10000
#
#     accuracy                           0.83     20000
#    macro avg       0.84      0.83      0.82     20000
# weighted avg       0.84      0.83      0.82     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## **Second model**

# %%
from tensorflow.keras.regularizers import l2
model2 = Sequential([
    Input(shape=(128, 128, 3)),  # Input layer specifying the input shape
    Flatten(),  # Flatten the input images
    Dense(512, activation='relu', kernel_regularizer=l2(0.04)),  # Hidden layer with 512 units and ReLU activation with L2 regularization
    Dense(256, activation='relu',kernel_regularizer=l2(0.05)),  # Hidden layer with 256 units and ReLU activation
    Dense(128, activation='relu'),  # Hidden layer with 128 units and ReLU activation
    Dense(64, activation='relu'),   # Hidden layer with 64 units and ReLU activation
    Dense(2, activation='softmax')  # Output layer with 2 units (assuming 2 classes) and softmax activation
])



# Compile the model
model2.compile(optimizer='adam',  # Adam optimizer
              loss='categorical_crossentropy',  # Categorical cross-entropy loss function
              metrics=['accuracy'])  # Monitor accuracy during training

# Print model summary
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 49152)             0
#
#  dense_15 (Dense)            (None, 512)               25166336
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dense_19 (Dense)            (None, 2)                 130
#
# ...
# Total params: 25,338,946
# Trainable params: 25,338,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history2 = model2.fit(
    train_dataset,
    epochs=10,
    validation_data=test_dataset,
    callbacks=[early_stopping]  # Pass the early stopping callback to the fit method
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 123s 78ms/step - loss: 2.6742 - accuracy: 0.5637 - val_loss: 0.8810 - val_accuracy: 0.5867
# Epoch 2/10
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.7697 - accuracy: 0.6014 - val_loss: 0.7626 - val_accuracy: 0.6202
# Epoch 3/10
# 1563/1563 [==============================] - 118s 75ms/step - loss: 0.6659 - accuracy: 0.6567 - val_loss: 0.6017 - val_accuracy: 0.6920
# Epoch 4/10
# 1563/1563 [==============================] - 105s 67ms/step - loss: 0.6267 - accuracy: 0.6722 - val_loss: 0.6005 - val_accuracy: 0.6844
# Epoch 5/10
# 1563/1563 [==============================] - 103s 66ms/step - loss: 0.6167 - accuracy: 0.6725 - val_loss: 0.6466 - val_accuracy: 0.6441
# Epoch 6/10
# 1563/1563 [==============================] - 104s 67ms/step - loss: 0.6141 - accuracy: 0.6729 - val_loss: 0.6063 - val_accuracy: 0.6741
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
# # Plot training & validation accuracy values
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# # Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred_probs = model2.predict(test_dataset)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)



# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 18s 58ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.61      0.87      0.72     10000
#      class 1       0.77      0.43      0.55     10000
#
#     accuracy                           0.65     20000
#    macro avg       0.69      0.65      0.64     20000
# weighted avg       0.69      0.65      0.64     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## **Grid Search**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Define the hyperparameter grid
regularization_factors = [0.06, 0.07, 0.08]
optimizers = ['adam', 'sgd']

# Placeholder to store the evaluation results
results = []
histories = []

# Grid search over the hyperparameters
for reg in regularization_factors:
    for opt in optimizers:
        model = Sequential([
            Input(shape=(128, 128, 3)),
            Flatten(),
            Dense(512, activation='relu', kernel_regularizer=l2(reg)),
            Dense(256, activation='relu', kernel_regularizer=l2(reg)),
            Dense(128, activation='relu', kernel_regularizer=l2(reg)),
            Dense(64, activation='relu', kernel_regularizer=l2(reg)),
            Dense(2, activation='softmax')
        ])
        
        model.compile(
            optimizer=opt,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the model
        history = model.fit(
            train_dataset,
            epochs=10,
            validation_data=test_dataset,
            callbacks=[early_stopping],
            verbose=1  # Set verbose to 1 to print out the progress
        )
        
        # Store the history
        histories.append(history)
        
        # Evaluate the model on the validation data
        val_accuracy = model.evaluate(test_dataset, verbose=0)[1]
        
        # Store the results
        results.append({
            'regularization': reg,
            'optimizer': opt,
            'validation_accuracy': val_accuracy
        })

# Identify the best configuration
best_result = max(results, key=lambda x: x['validation_accuracy'])
print("Best configuration:", best_result)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 104s 66ms/step - loss: 4.4821 - accuracy: 0.5586 - val_loss: 1.1867 - val_accuracy: 0.4926
# Epoch 2/10
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.8859 - accuracy: 0.5513 - val_loss: 0.7439 - val_accuracy: 0.5000
# Epoch 3/10
# 1563/1563 [==============================] - 97s 62ms/step - loss: 0.7112 - accuracy: 0.5006 - val_loss: 0.6962 - val_accuracy: 0.5000
# Epoch 4/10
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.6941 - accuracy: 0.4999 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 5/10
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.6933 - accuracy: 0.4991 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/10
# 1563/1563 [==============================] - 98s 62ms/step - loss: 0.6933 - accuracy: 0.4996 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
# Plot training & validation accuracy values for the best model
best_model_index = results.index(best_result)
best_history = histories[best_model_index]


# Plot training & validation accuracy values
plt.plot(best_history.history['accuracy'])
plt.plot(best_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(best_history.history['loss'])
plt.plot(best_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
# Get the best model
best_model = model

# Assuming you have already trained and obtained predictions from your best model

# Get predicted probabilities for the test dataset
y_pred_probs = best_model.predict(test_dataset)

# Convert probabilities to class labels (assuming binary classification)
y_pred = np.argmax(y_pred_probs, axis=1)

# Get true labels from the test dataset
y_true = test_dataset.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Compute and display classification report
target_names = ['class 0', 'class 1']  # Replace with your actual class labels
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 313/313 [==============================] - 19s 62ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.65      0.70      0.68     10000
#      class 1       0.68      0.62      0.65     10000
#
#     accuracy                           0.66     20000
#    macro avg       0.66      0.66      0.66     20000
# weighted avg       0.66      0.66      0.66     20000

# %%
import seaborn as sns

#Plot confusion matrix as heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_dataset.class_indices.keys(),
            yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# Initialize the model
model = Sequential()
# Add convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flatten the output of convolutional layers
model.add(Flatten())
# Add dense layers with dropout
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.6))  # Adding dropout with rate 0.5
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))  # Adding dropout with rate 0.5
model.add(Dense(2, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      896
#
#  batch_normalization_2 (Batc  (None, 126, 126, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 128)               3211392
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
# ...

# %%
history = model.fit(
    train_dataset,
    epochs=10,
    validation_data=test_dataset
)
# Out:
# Epoch 1/10
#  209/1563 [===>..........................] - ETA: 10:19 - loss: 0.7575 - accuracy: 0.6894
